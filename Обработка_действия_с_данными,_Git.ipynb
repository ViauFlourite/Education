# %% [markdown]
# <a href="https://colab.research.google.com/github/ViauFlourite/Education/blob/main/%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D0%B4%D0%B5%D0%B9%D1%81%D1%82%D0%B2%D0%B8%D1%8F_%D1%81_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8%2C_Git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df.drop(1, axis=0, inplace=True)
df
# Out:
#    x  y
# 0  1  2
# 2  2  1

# %% [markdown]
# *удаляем строку*

# %%
df.reset_index(drop=True)
# Out:
#    x  y
# 0  1  2
# 1  2  1

# %%
del df['y'] # df.drop('x', axis=1)
df
# Out:
#    x
# 0  1
# 1  3
# 2  2

# %% [markdown]
# *удаляем столбцы*

# %%
df1 = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df2 = pd.DataFrame({'x':[3,1,2], 'y':[0,2,2]})
print(df1)
print(df2)
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1
#    x  y
# 0  3  0
# 1  1  2
# 2  2  2

# %%
df1>=df2
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df1[df1 >1]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN

# %%
df2[(df2 < 2) & (df2 >0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN

# %%
df2[(df2 < 1) | (df2 >2)]
# Out:
#      x    y
# 0  3.0  0.0
# 1  NaN  NaN
# 2  NaN  NaN

# %%
data = {'Имя': ['Анна', 'Борис', None, 'Джон'],
        'Возраст': [25, 30, 28, None]}
df = pd.DataFrame(data)
df
# Out:
#      Имя  Возраст
# 0   Анна     25.0
# 1  Борис     30.0
# 2   None     28.0
# 3   Джон      NaN

# %%
x = df.isnull()
x
# Out:
#      Имя  Возраст
# 0  False    False
# 1  False    False
# 2   True    False
# 3  False     True

# %%
df.isnull().loc[x["Имя"] == True]
# Out:
#     Имя  Возраст
# 2  True    False

# %%
data = {'Цвет': ['Красный', 'Синий', 'Зеленый', 'Красный', 'Желтый', 'Зеленый']}
df = pd.DataFrame(data)

# %%
unique_colors = df['Цвет'].unique()
unique_colors
# Out:
# array(['Красный', 'Синий', 'Зеленый', 'Желтый'], dtype=object)

# %% [markdown]
# --------------------------------------------------------------------
# GIT

# %%
1+1
# Out:
# 2
